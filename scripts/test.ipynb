# %%
# !pip install pypandoc
# Out:
# ...
# WARNING: Ignoring invalid distribution ~bt-core (C:\Users\ASUS\miniconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~bt-core (C:\Users\ASUS\miniconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~bt-core (C:\Users\ASUS\miniconda3\Lib\site-packages)

# %%
import pypandoc

input_file = r"D:\hanoi-smart-tourism-lakehouse\docs\report.md"

# convert sang HTML
html = pypandoc.convert_file(input_file, 'html')

# lưu file HTML
with open(r"D:\hanoi-smart-tourism-lakehouse\docs\report.html", "w", encoding="utf-8") as f:
    f.write(html)

print("Đã tạo report.html")
# Out:
# Đã tạo report.html
